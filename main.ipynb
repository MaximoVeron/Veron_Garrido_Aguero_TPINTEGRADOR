# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset_fusionado.csv')

# %%
df_moded = pd.get_dummies(df, columns=['ocupacion', 'app_mas_usada', 'categoria_app_principal', 'intento_reducir_pantalla','origen'])

# %%
rango_edad_map = {
    '18-25': 2,
    '26-35': 3,
    'Menor de 17': 1,
    'Más de 35': 4,
}
horas_pantalla_map = {
    'Menos de 2 horas': 1,
    'Entre 2 a 4 horas': 2,
    'Entre 4 a 6 horas': 3,
    'Entre 6 a 8 horas': 4,
    'Más de 8 horas': 5
}
frecuencia_map = {
    'Casi nunca': 1,
    'Rara vez': 2,
    'A veces': 3,
    'Frecuentemente': 4,
    'Casi siempre': 5
}
interrupciones_map = {
    'Nunca puedo evitar las interrupciones': 1,
    'Casi nunca': 2,
    'Algunas veces': 3,
    'Casi siempre': 4,
    'Siempre puedo trabajar sin interrupciones': 5
}

# %%
df_moded["rango_edad"] = df_moded["rango_edad"].map(rango_edad_map)
df_moded["horas_diarias_pantalla"] = df_moded["horas_diarias_pantalla"].map(horas_pantalla_map)
df_moded["frecuencia_completar_tareas"] = df_moded["frecuencia_completar_tareas"].map(frecuencia_map)
df_moded["frecuencia_concentracion_sin_celular"] = df_moded["frecuencia_concentracion_sin_celular"].map(interrupciones_map)

# %%
df_moded.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 22 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   rango_edad                                    303 non-null    int64
#  1   horas_diarias_pantalla                        303 non-null    int64
#  2   frecuencia_completar_tareas                   303 non-null    int64
#  3   frecuencia_concentracion_sin_celular          303 non-null    int64
#  4   ocupacion_Estudiante Secundario               303 non-null    bool
#  5   ocupacion_Estudiante Universitario/Terciario  303 non-null    bool
#  6   ocupacion_Otros                               303 non-null    bool
#  7   app_mas_usada_Facebook                        303 non-null    bool
#  8   app_mas_usada_Instagram                       303 non-null    bool
#  9   app_mas_usada_Otros                           303 non-null    bool
# ...

# %%
df_moded.describe()
# Out:
#        rango_edad  horas_diarias_pantalla  frecuencia_completar_tareas  \
# count  303.000000              303.000000                   303.000000
# mean     2.280528                3.244224                     3.224422
# std      0.933474                1.201444                     1.240513
# min      1.000000                1.000000                     1.000000
# 25%      2.000000                2.000000                     2.000000
# 50%      2.000000                3.000000                     3.000000
# 75%      3.000000                4.000000                     4.000000
# max      4.000000                5.000000                     5.000000
#
#        frecuencia_concentracion_sin_celular
# count                            303.000000
# mean                               2.996700
# std                                1.172246
# min                                1.000000
# 25%                                2.000000
# 50%                                3.000000
# ...
